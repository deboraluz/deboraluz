# %% [markdown]
# <a href="https://colab.research.google.com/github/deboraluz/deboraluz/blob/main/M5_exerc%C3%ADcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Bem vindo à calculadora!')

nome = input('Qual é o seu nome?')

while True:
  print(f'\nOlá, {nome}!')
  print('Escolha uma operação matemática:')
  print('1 - Soma')
  print('2 - Subtração')
  print('3 - Multiplicação')
  print('4 - Divisão')
  print('5 - Sair')

  opcao = input('Digite a opção desejada:')

  if opcao == '5':
    print('Obrigado por usar a calculadora!')
    break # Parar se for opção 5

  # Só perguntar se não for opção 5
  num1 = float(input('Digite o primeiro número:'))
  num2 = float(input('Digite o segundo número:'))

  if opcao == '1':
    resultado = num1 + num2
    print(f'O resultado da soma é: {resultado}')
  elif opcao == '2':
    resultado = num1 - num2
    print(f'O resultado da subtração é: {resultado}')
  elif opcao == '3':
    resultado = num1 * num2
    print(f'O resultado da multiplicação é: {resultado}')
  elif opcao == '4':
    if num2 == 0:
      print('Não é possível dividir por zero!')
    else:
      resultado = num1 / num2
      print(f'O resultado da divisão é: {resultado}')
  else:
    print('Opção inexistente, tente outra.')
# Out:
# Bem vindo à calculadora!
# Qual é o seu nome?Debora
#
# Olá, Debora!
# Escolha uma operação matemática:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite a opção desejada:2
# Digite o primeiro número:20
# Digite o segundo número:6
# O resultado da subtração é: 14.0
#
# Olá, Debora!
# Escolha uma operação matemática:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite a opção desejada:4
# Digite o primeiro número:20
# Digite o segundo número:6
# O resultado da divisão é: 3.3333333333333335
#
# Olá, Debora!
# Escolha uma operação matemática:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite a opção desejada:5
# Obrigado por usar a calculadora!
